# %% [markdown]
# <a href="https://colab.research.google.com/github/jeguns/Manipulacion-de-datos-con-R-y-Python/blob/main/Python/9%20-%20Manipulaci%C3%B3n%20de%20datos/U9_Manipulaci%C3%B3n_de_datos_en_Python_P2%20-%20Codigos%20en%20clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejemplo inicial

# %%
import pandas as pd

df1 = pd.DataFrame({'id': [1, 2, 3, 4], 'nombre': ["Ana", "Beto", "Carlos", "Diana"]})
df2 = pd.DataFrame({'id': [3, 4, 5, 6], 'puntaje': [85, 90, 88, 92]})

# %%
df1
# Out:
#    id  nombre
# 0   1     Ana
# 1   2    Beto
# 2   3  Carlos
# 3   4   Diana

# %%
df2
# Out:
#    id  puntaje
# 0   3       85
# 1   4       90
# 2   5       88
# 3   6       92

# %%
pd.merge(df1, df2, on='id', how='left')
# Out:
#    id  nombre  puntaje
# 0   1     Ana      NaN
# 1   2    Beto      NaN
# 2   3  Carlos     85.0
# 3   4   Diana     90.0

# %%
pd.merge(df1, df2, on='id', how='right')
# Out:
#    id  nombre  puntaje
# 0   3  Carlos       85
# 1   4   Diana       90
# 2   5     NaN       88
# 3   6     NaN       92

# %%
pd.merge(df1, df2, on='id', how='inner')
# Out:
#    id  nombre  puntaje
# 0   3  Carlos       85
# 1   4   Diana       90

# %%
pd.merge(df1, df2, on='id', how='outer')
# Out:
#    id  nombre  puntaje
# 0   1     Ana      NaN
# 1   2    Beto      NaN
# 2   3  Carlos     85.0
# 3   4   Diana     90.0
# 4   5     NaN     88.0
# 5   6     NaN     92.0

# %% [markdown]
# ## Lectura

# %%
import pandas as pd
datos_A = pd.read_csv('U9 - DATOS2.csv', encoding='latin1')
datos_B = pd.read_csv('U9 - DATOS3.csv', encoding='latin1')

# %% [markdown]
# ## Repaso

# %%
datos1a = datos_A[['CONGLOME', 'VIVIENDA', 'HOGAR', 'UBIGEO', 'RESULT', 'P101', 'P104A']] # selección de variables
datos1a['CODIGO'] = datos1a['CONGLOME'].astype(str) + datos1a['VIVIENDA'].astype(str) + datos1a['HOGAR'].astype(str) # creación de variable
datos1a = datos1a[datos1a['UBIGEO'] == 150114] # filtro según una condición
datos1a = datos1a.drop(columns=['CONGLOME', 'VIVIENDA', 'HOGAR', 'UBIGEO']) # elimino variables
datos1a
# Out:
# <ipython-input-10-38f0c9adb830>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos1a['CODIGO'] = datos1a['CONGLOME'].astype(str) + datos1a['VIVIENDA'].astype(str) + datos1a['HOGAR'].astype(str) # creación de variable
#       RESULT P101 P104A      CODIGO
# 5813       3               17939811
# 5814       4              179392311
# 5815       2    1     4   179394911
# 5816       2    1     4   179396211
# 5817       3              179397611
# 5818       3              179399011
# 5819       3             1793911611
# 5820       3             1793912911

# %%
datos1 = (
    datos_A[['CONGLOME', 'VIVIENDA', 'HOGAR', 'UBIGEO', 'RESULT', 'P101', 'P104A']] # selección de variables
    .copy()
    .assign(CODIGO=lambda df: df['CONGLOME'].astype(str) + df['VIVIENDA'].astype(str) + df['HOGAR'].astype(str)) # creación de variable
    .query('UBIGEO == 150114') # filtro
    .drop(columns=['CONGLOME', 'VIVIENDA', 'HOGAR', 'UBIGEO']) # elimino variables
)
datos1 # viviendas y hogares
# Out:
#       RESULT P101 P104A      CODIGO
# 5813       3               17939811
# 5814       4              179392311
# 5815       2    1     4   179394911
# 5816       2    1     4   179396211
# 5817       3              179397611
# 5818       3              179399011
# 5819       3             1793911611
# 5820       3             1793912911

# %%
datos1a.equals(datos1)
# Out:
# True

# %%
datos2 = (
    datos_B[['CONGLOME', 'VIVIENDA', 'HOGAR', 'UBIGEO', 'P207', 'P208A']]
    .copy()
    .assign(codigo=lambda df: df['CONGLOME'].astype(str) + df['VIVIENDA'].astype(str) + df['HOGAR'].astype(str))
    .query('UBIGEO == 150114') # distrito de La Molina
    .drop(columns=['CONGLOME', 'VIVIENDA', 'HOGAR', 'UBIGEO'])
)
datos2 # miembros del hogar
# Out:
#       P207 P208A     codigo
# 14472    1    76  179394911
# 14473    2    78  179394911
# 14474    1    45  179394911
# 14475    1    32  179396211
# 14476    2    36  179396211
# 14477    2     4  179396211
# 14478    2    22  179396211
# 14479    2    25  179396211

# %% [markdown]
# ## Integración de data frames

# %%
datos3 = pd.merge(datos1, datos2, left_on='CODIGO', right_on='codigo', how='left', indicator = True)
datos3
# Out:
#     RESULT P101 P104A      CODIGO P207 P208A     codigo     _merge
# 0        3               17939811  NaN   NaN        NaN  left_only
# 1        4              179392311  NaN   NaN        NaN  left_only
# 2        2    1     4   179394911    1    76  179394911       both
# 3        2    1     4   179394911    2    78  179394911       both
# 4        2    1     4   179394911    1    45  179394911       both
# 5        2    1     4   179396211    1    32  179396211       both
# 6        2    1     4   179396211    2    36  179396211       both
# 7        2    1     4   179396211    2     4  179396211       both
# 8        2    1     4   179396211    2    22  179396211       both
# 9        2    1     4   179396211    2    25  179396211       both
# 10       3              179397611  NaN   NaN        NaN  left_only
# 11       3              179399011  NaN   NaN        NaN  left_only
# 12       3             1793911611  NaN   NaN        NaN  left_only
# ...

# %%
datos4 = pd.merge(datos1, datos2, left_on='CODIGO', right_on='codigo', how='right', indicator = True)
datos4
# Out:
#    RESULT P101 P104A     CODIGO P207 P208A     codigo _merge
# 0       2    1     4  179394911    1    76  179394911   both
# 1       2    1     4  179394911    2    78  179394911   both
# 2       2    1     4  179394911    1    45  179394911   both
# 3       2    1     4  179396211    1    32  179396211   both
# 4       2    1     4  179396211    2    36  179396211   both
# 5       2    1     4  179396211    2     4  179396211   both
# 6       2    1     4  179396211    2    22  179396211   both
# 7       2    1     4  179396211    2    25  179396211   both

# %%
datos5 = pd.merge(datos1, datos2, left_on='CODIGO', right_on='codigo', how='inner', indicator = True)
datos5
# Out:
#    RESULT P101 P104A     CODIGO P207 P208A     codigo _merge
# 0       2    1     4  179394911    1    76  179394911   both
# 1       2    1     4  179394911    2    78  179394911   both
# 2       2    1     4  179394911    1    45  179394911   both
# 3       2    1     4  179396211    1    32  179396211   both
# 4       2    1     4  179396211    2    36  179396211   both
# 5       2    1     4  179396211    2     4  179396211   both
# 6       2    1     4  179396211    2    22  179396211   both
# 7       2    1     4  179396211    2    25  179396211   both

# %%
datos6 = pd.merge(datos1, datos2, left_on='CODIGO', right_on='codigo', how='outer', indicator = True)
datos6
# Out:
#     RESULT P101 P104A      CODIGO P207 P208A     codigo     _merge
# 0        3             1793911611  NaN   NaN        NaN  left_only
# 1        3             1793912911  NaN   NaN        NaN  left_only
# 2        4              179392311  NaN   NaN        NaN  left_only
# 3        2    1     4   179394911    1    76  179394911       both
# 4        2    1     4   179394911    2    78  179394911       both
# 5        2    1     4   179394911    1    45  179394911       both
# 6        2    1     4   179396211    1    32  179396211       both
# 7        2    1     4   179396211    2    36  179396211       both
# 8        2    1     4   179396211    2     4  179396211       both
# 9        2    1     4   179396211    2    22  179396211       both
# 10       2    1     4   179396211    2    25  179396211       both
# 11       3              179397611  NaN   NaN        NaN  left_only
# 12       3               17939811  NaN   NaN        NaN  left_only
# ...

# %% [markdown]
# ## Ordenamiento de datos

# %%
datos5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RESULT  8 non-null      int64
#  1   P101    8 non-null      object
#  2   P104A   8 non-null      object
#  3   CODIGO  8 non-null      object
#  4   P207    8 non-null      object
#  5   P208A   8 non-null      object
#  6   codigo  8 non-null      object
#  7   _merge  8 non-null      category
# dtypes: category(1), int64(1), object(6)
# memory usage: 716.0+ bytes

# %%
datos5.sort_values(by='P208A') # P208A es string. Ordena primero colocando el dígito 2, luego 3, de ahí el 4, etc
# Out:
#    RESULT P101 P104A     CODIGO P207 P208A     codigo _merge
# 6       2    1     4  179396211    2    22  179396211   both
# 7       2    1     4  179396211    2    25  179396211   both
# 3       2    1     4  179396211    1    32  179396211   both
# 4       2    1     4  179396211    2    36  179396211   both
# 5       2    1     4  179396211    2     4  179396211   both
# 2       2    1     4  179394911    1    45  179394911   both
# 0       2    1     4  179394911    1    76  179394911   both
# 1       2    1     4  179394911    2    78  179394911   both

# %%
datos5.sort_values(by='P208A', ascending=False)
# Out:
#    RESULT P101 P104A     CODIGO P207 P208A     codigo _merge
# 1       2    1     4  179394911    2    78  179394911   both
# 0       2    1     4  179394911    1    76  179394911   both
# 2       2    1     4  179394911    1    45  179394911   both
# 5       2    1     4  179396211    2     4  179396211   both
# 4       2    1     4  179396211    2    36  179396211   both
# 3       2    1     4  179396211    1    32  179396211   both
# 7       2    1     4  179396211    2    25  179396211   both
# 6       2    1     4  179396211    2    22  179396211   both

# %%
datos5['P208A'] = pd.to_numeric(datos5['P208A']) # convierto a numérico
datos5.sort_values(by='P208A', ascending=False)
# Out:
#    RESULT P101 P104A     CODIGO P207  P208A     codigo _merge
# 1       2    1     4  179394911    2     78  179394911   both
# 0       2    1     4  179394911    1     76  179394911   both
# 2       2    1     4  179394911    1     45  179394911   both
# 4       2    1     4  179396211    2     36  179396211   both
# 3       2    1     4  179396211    1     32  179396211   both
# 7       2    1     4  179396211    2     25  179396211   both
# 6       2    1     4  179396211    2     22  179396211   both
# 5       2    1     4  179396211    2      4  179396211   both
