# %% [markdown]
# <a href="https://colab.research.google.com/github/jeguns/Manipulacion-de-datos-con-R-y-Python/blob/main/Python/9%20-%20Manipulaci%C3%B3n%20de%20datos/U9_Manipulaci%C3%B3n_de_datos_en_Python_P3%20-%20Codigos%20en%20clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Lectura

# %%
import pandas as pd
from datetime import datetime, timedelta
datos = pd.read_excel('U9 - DATOS4.xlsx', skiprows=14)
datos.head(5)
# Out:
#   AÑO / MES / DÍA      HORA   TEMPERATURA (°C)   PRECIPITACIÓN (mm/hora)   \
# 0       2024-10-01  00:00:00               14.8                       0.0
# 1       2024-10-01  01:00:00               15.2                       0.0
# 2       2024-10-01  02:00:00               15.0                       0.0
# 3       2024-10-01  03:00:00               14.8                       0.0
# 4       2024-10-01  04:00:00               14.7                       0.0
#
#    HUMEDAD (%)   DIRECCION DEL VIENTO (°)   VELOCIDAD DEL VIENTO (m/s)
# 0            94                        264                          0.2
# 1            90                         90                          1.5
# 2            92                        272                          1.0
# 3            93                        321                          0.2
# 4            93                        310                          0.8

# %%
print("Columnas:", datos.columns)
# Out:
# Columnas: Index(['AÑO / MES / DÍA ', 'HORA ', 'TEMPERATURA (°C) ',
#        'PRECIPITACIÓN (mm/hora) ', 'HUMEDAD (%) ', 'DIRECCION DEL VIENTO (°) ',
#        'VELOCIDAD DEL VIENTO (m/s) '],
#       dtype='object')

# %%
datos[['HORA ']]
# Out:
#         HORA
# 0    00:00:00
# 1    01:00:00
# 2    02:00:00
# 3    03:00:00
# 4    04:00:00
# ..        ...
# 103  07:00:00
# 104  08:00:00
# 105  09:00:00
# 106  10:00:00
# 107  11:00:00
#
# [108 rows x 1 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   AÑO / MES / DÍA              108 non-null    datetime64[ns]
#  1   HORA                         108 non-null    object
#  2   TEMPERATURA (°C)             108 non-null    float64
#  3   PRECIPITACIÓN (mm/hora)      108 non-null    float64
#  4   HUMEDAD (%)                  108 non-null    int64
#  5   DIRECCION DEL VIENTO (°)     108 non-null    int64
#  6   VELOCIDAD DEL VIENTO (m/s)   108 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Repaso

# %%
datos1 = (datos
    .copy()
    .rename(columns={datos.columns[0]: 'FECHA',
                     datos.columns[1]: 'HORA',
                     datos.columns[2]: 'TEMP',
                     datos.columns[3]: 'PRECI',
                     datos.columns[4]: 'HUMEDAD',
                     datos.columns[5]: 'DIRECVEL',
                     datos.columns[6]: 'VELOCVEL'})
    .assign(FECHA    = lambda x: pd.to_datetime(x['FECHA'], format='%Y-%m-%d'),
            DIRECVEL = lambda x: pd.to_numeric(x['DIRECVEL'], errors='coerce'))
)

# %%
datos1.head()
# Out:
#        FECHA      HORA  TEMP  PRECI  HUMEDAD  DIRECVEL  VELOCVEL
# 0 2024-10-01  00:00:00  14.8    0.0       94       264       0.2
# 1 2024-10-01  01:00:00  15.2    0.0       90        90       1.5
# 2 2024-10-01  02:00:00  15.0    0.0       92       272       1.0
# 3 2024-10-01  03:00:00  14.8    0.0       93       321       0.2
# 4 2024-10-01  04:00:00  14.7    0.0       93       310       0.8

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   AÑO / MES / DÍA              108 non-null    datetime64[ns]
#  1   HORA                         108 non-null    object
#  2   TEMPERATURA (°C)             108 non-null    float64
#  3   PRECIPITACIÓN (mm/hora)      108 non-null    float64
#  4   HUMEDAD (%)                  108 non-null    int64
#  5   DIRECCION DEL VIENTO (°)     108 non-null    int64
#  6   VELOCIDAD DEL VIENTO (m/s)   108 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 6.0+ KB

# %%
datos1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   FECHA     108 non-null    datetime64[ns]
#  1   HORA      108 non-null    object
#  2   TEMP      108 non-null    float64
#  3   PRECI     108 non-null    float64
#  4   HUMEDAD   108 non-null    int64
#  5   DIRECVEL  108 non-null    int64
#  6   VELOCVEL  108 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 6.0+ KB

# %%
Q1 = datos1['DIRECVEL'].quantile(0.25)
Q3 = datos1['DIRECVEL'].quantile(0.75)
LI = Q1 - 1.5 * (Q3 - Q1)  # límite inferior
LS = Q3 + 1.5 * (Q3 - Q1)  # límite superior

print("Q1:", Q1)
print("Q3:", Q3)
print("Límite inferior:", LI)
print("Límite superior:", LS)
# Out:
# Q1: 270.0
# Q3: 295.0
# Límite inferior: 232.5
# Límite superior: 332.5

# %%
datos2 = datos1[(datos1['DIRECVEL'] > LI) & (datos1['DIRECVEL'] < LS)]
datos2.head() # no atípicos
# Out:
#        FECHA      HORA  TEMP  PRECI  HUMEDAD  DIRECVEL  VELOCVEL
# 0 2024-10-01  00:00:00  14.8    0.0       94       264       0.2
# 2 2024-10-01  02:00:00  15.0    0.0       92       272       1.0
# 3 2024-10-01  03:00:00  14.8    0.0       93       321       0.2
# 4 2024-10-01  04:00:00  14.7    0.0       93       310       0.8
# 5 2024-10-01  05:00:00  14.7    0.0       94       293       0.7

# %%
datos3 = datos1[(datos1['DIRECVEL'] < LI) | (datos1['DIRECVEL'] > LS)]
datos3.head() # atípicos
# Out:
#         FECHA      HORA  TEMP  PRECI  HUMEDAD  DIRECVEL  VELOCVEL
# 1  2024-10-01  01:00:00  15.2    0.0       90        90       1.5
# 25 2024-10-02  01:00:00  14.8    0.0       94       338       0.6
# 26 2024-10-02  02:00:00  15.1    0.0       92       179       0.9
# 48 2024-10-03  00:00:00  13.7    0.0       94       206       0.5
# 53 2024-10-03  05:00:00  13.9    0.0       96       349       0.9

# %% [markdown]
# Otros filtros de valores atípicos: Z-Score (datos normales), Hampel (datos secuenciales), Tukey (datos asimétricos).

# %% [markdown]
# ## pivot wider (.pivot)

# %% [markdown]
# Cambiamos a formato ancho

# %%
datos1.head(4)
# Out:
#        FECHA      HORA  TEMP  PRECI  HUMEDAD  DIRECVEL  VELOCVEL
# 0 2024-10-01  00:00:00  14.8    0.0       94       264       0.2
# 1 2024-10-01  01:00:00  15.2    0.0       90        90       1.5
# 2 2024-10-01  02:00:00  15.0    0.0       92       272       1.0
# 3 2024-10-01  03:00:00  14.8    0.0       93       321       0.2

# %%
datos1.drop(columns=['PRECI', 'HUMEDAD', 'DIRECVEL', 'VELOCVEL'])
# Out:
#          FECHA      HORA  TEMP
# 0   2024-10-01  00:00:00  14.8
# 1   2024-10-01  01:00:00  15.2
# 2   2024-10-01  02:00:00  15.0
# 3   2024-10-01  03:00:00  14.8
# 4   2024-10-01  04:00:00  14.7
# ..         ...       ...   ...
# 103 2024-10-05  07:00:00  15.6
# 104 2024-10-05  08:00:00  19.5
# 105 2024-10-05  09:00:00  21.4
# 106 2024-10-05  10:00:00  22.3
# 107 2024-10-05  11:00:00  20.9
#
# [108 rows x 3 columns]

# %%
(datos1
 .drop(columns=['PRECI', 'HUMEDAD', 'DIRECVEL', 'VELOCVEL'])
 .pivot(index='FECHA', columns='HORA', values='TEMP'))
# Out:
# HORA        00:00:00  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  \
# FECHA
# 2024-10-01      14.8      15.2      15.0      14.8      14.7      14.7
# 2024-10-02      14.9      14.8      15.1      14.6      14.5      14.4
# 2024-10-03      13.7      14.3      13.8      13.2      13.8      13.9
# 2024-10-04      16.3      15.6      14.6      14.9      15.0      14.3
# 2024-10-05      15.2      14.9      14.7      14.8      14.3      13.3
#
# HORA        06:00:00  07:00:00  08:00:00  09:00:00  ...  14:00:00  15:00:00  \
# FECHA                                               ...
# 2024-10-01      14.6      15.6      17.6      19.8  ...      23.0      21.8
# 2024-10-02      14.4      14.7      15.1      15.8  ...      21.9      19.3
# 2024-10-03      14.0      14.4      15.8      19.2  ...      25.9      22.6
# 2024-10-04      13.6      16.6      19.3      20.0  ...      22.4      22.3
# 2024-10-05      13.2      15.6      19.5      21.4  ...       NaN       NaN
#
# HORA        16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  21:00:00  \
# FECHA
# 2024-10-01      19.7      17.7      16.9      15.9      15.8      15.2
# 2024-10-02      20.2      19.3      17.7      16.0      15.1      14.6
# 2024-10-03      21.9      21.4      19.0      18.2      16.9      16.3
# 2024-10-04      21.5      20.6      18.3      17.6      16.1      16.0
# 2024-10-05       NaN       NaN       NaN       NaN       NaN       NaN
#
# HORA        22:00:00  23:00:00
# FECHA
# 2024-10-01      15.2      15.2
# 2024-10-02      14.4      14.0
# 2024-10-03      15.7      16.2
# 2024-10-04      15.4      14.8
# 2024-10-05       NaN       NaN
#
# [5 rows x 24 columns]

# %%
datos4 = (datos1
          .drop(columns=['PRECI', 'HUMEDAD', 'DIRECVEL', 'VELOCVEL'])
          .pivot(index='FECHA', columns='HORA', values='TEMP'))
datos4.head()
# Out:
# HORA        00:00:00  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  \
# FECHA
# 2024-10-01      14.8      15.2      15.0      14.8      14.7      14.7
# 2024-10-02      14.9      14.8      15.1      14.6      14.5      14.4
# 2024-10-03      13.7      14.3      13.8      13.2      13.8      13.9
# 2024-10-04      16.3      15.6      14.6      14.9      15.0      14.3
# 2024-10-05      15.2      14.9      14.7      14.8      14.3      13.3
#
# HORA        06:00:00  07:00:00  08:00:00  09:00:00  ...  14:00:00  15:00:00  \
# FECHA                                               ...
# 2024-10-01      14.6      15.6      17.6      19.8  ...      23.0      21.8
# 2024-10-02      14.4      14.7      15.1      15.8  ...      21.9      19.3
# 2024-10-03      14.0      14.4      15.8      19.2  ...      25.9      22.6
# 2024-10-04      13.6      16.6      19.3      20.0  ...      22.4      22.3
# 2024-10-05      13.2      15.6      19.5      21.4  ...       NaN       NaN
#
# HORA        16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  21:00:00  \
# FECHA
# 2024-10-01      19.7      17.7      16.9      15.9      15.8      15.2
# 2024-10-02      20.2      19.3      17.7      16.0      15.1      14.6
# 2024-10-03      21.9      21.4      19.0      18.2      16.9      16.3
# 2024-10-04      21.5      20.6      18.3      17.6      16.1      16.0
# 2024-10-05       NaN       NaN       NaN       NaN       NaN       NaN
#
# HORA        22:00:00  23:00:00
# FECHA
# 2024-10-01      15.2      15.2
# 2024-10-02      14.4      14.0
# 2024-10-03      15.7      16.2
# 2024-10-04      15.4      14.8
# 2024-10-05       NaN       NaN
#
# [5 rows x 24 columns]

# %%
datos4 = datos4.rename(columns={datos4.columns[0]: 'Medianoche'})
datos4.head()
# Out:
# HORA        Medianoche  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  \
# FECHA
# 2024-10-01        14.8      15.2      15.0      14.8      14.7      14.7
# 2024-10-02        14.9      14.8      15.1      14.6      14.5      14.4
# 2024-10-03        13.7      14.3      13.8      13.2      13.8      13.9
# 2024-10-04        16.3      15.6      14.6      14.9      15.0      14.3
# 2024-10-05        15.2      14.9      14.7      14.8      14.3      13.3
#
# HORA        06:00:00  07:00:00  08:00:00  09:00:00  ...  14:00:00  15:00:00  \
# FECHA                                               ...
# 2024-10-01      14.6      15.6      17.6      19.8  ...      23.0      21.8
# 2024-10-02      14.4      14.7      15.1      15.8  ...      21.9      19.3
# 2024-10-03      14.0      14.4      15.8      19.2  ...      25.9      22.6
# 2024-10-04      13.6      16.6      19.3      20.0  ...      22.4      22.3
# 2024-10-05      13.2      15.6      19.5      21.4  ...       NaN       NaN
#
# HORA        16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  21:00:00  \
# FECHA
# 2024-10-01      19.7      17.7      16.9      15.9      15.8      15.2
# 2024-10-02      20.2      19.3      17.7      16.0      15.1      14.6
# 2024-10-03      21.9      21.4      19.0      18.2      16.9      16.3
# 2024-10-04      21.5      20.6      18.3      17.6      16.1      16.0
# 2024-10-05       NaN       NaN       NaN       NaN       NaN       NaN
#
# HORA        22:00:00  23:00:00
# FECHA
# 2024-10-01      15.2      15.2
# 2024-10-02      14.4      14.0
# 2024-10-03      15.7      16.2
# 2024-10-04      15.4      14.8
# 2024-10-05       NaN       NaN
#
# [5 rows x 24 columns]

# %%
datos4.columns
# Out:
# Index(['Medianoche',     01:00:00,     02:00:00,     03:00:00,     04:00:00,
#            05:00:00,     06:00:00,     07:00:00,     08:00:00,     09:00:00,
#            10:00:00,     11:00:00,     12:00:00,     13:00:00,     14:00:00,
#            15:00:00,     16:00:00,     17:00:00,     18:00:00,     19:00:00,
#            20:00:00,     21:00:00,     22:00:00,     23:00:00],
#       dtype='object', name='HORA')

# %%
Q1 = datos4['Medianoche'].quantile(0.25)
Q3 = datos4['Medianoche'].quantile(0.75)
LI = Q1 - 1.5 * (Q3 - Q1)  # límite inferior
LS = Q3 + 1.5 * (Q3 - Q1)  # límite superior

print("Q1:", Q1)
print("Q3:", Q3)
print("Límite inferior:", LI)
print("Límite superior:", LS)
# Out:
# Q1: 14.8
# Q3: 15.2
# Límite inferior: 14.200000000000003
# Límite superior: 15.799999999999997

# %%
datos5 = datos4[(datos4['Medianoche'] < LI) | (datos4['Medianoche'] > LS)]
datos5.head() # atípicos
# Out:
# HORA        Medianoche  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  \
# FECHA
# 2024-10-03        13.7      14.3      13.8      13.2      13.8      13.9
# 2024-10-04        16.3      15.6      14.6      14.9      15.0      14.3
#
# HORA        06:00:00  07:00:00  08:00:00  09:00:00  ...  14:00:00  15:00:00  \
# FECHA                                               ...
# 2024-10-03      14.0      14.4      15.8      19.2  ...      25.9      22.6
# 2024-10-04      13.6      16.6      19.3      20.0  ...      22.4      22.3
#
# HORA        16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  21:00:00  \
# FECHA
# 2024-10-03      21.9      21.4      19.0      18.2      16.9      16.3
# 2024-10-04      21.5      20.6      18.3      17.6      16.1      16.0
#
# HORA        22:00:00  23:00:00
# FECHA
# 2024-10-03      15.7      16.2
# 2024-10-04      15.4      14.8
#
# [2 rows x 24 columns]

# %%
datos6 = datos4[(datos4['Medianoche'] > LI) & (datos4['Medianoche'] < LS)]
datos6.head() # no atípicos
# Out:
# HORA        Medianoche  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  \
# FECHA
# 2024-10-01        14.8      15.2      15.0      14.8      14.7      14.7
# 2024-10-02        14.9      14.8      15.1      14.6      14.5      14.4
# 2024-10-05        15.2      14.9      14.7      14.8      14.3      13.3
#
# HORA        06:00:00  07:00:00  08:00:00  09:00:00  ...  14:00:00  15:00:00  \
# FECHA                                               ...
# 2024-10-01      14.6      15.6      17.6      19.8  ...      23.0      21.8
# 2024-10-02      14.4      14.7      15.1      15.8  ...      21.9      19.3
# 2024-10-05      13.2      15.6      19.5      21.4  ...       NaN       NaN
#
# HORA        16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  21:00:00  \
# FECHA
# 2024-10-01      19.7      17.7      16.9      15.9      15.8      15.2
# 2024-10-02      20.2      19.3      17.7      16.0      15.1      14.6
# 2024-10-05       NaN       NaN       NaN       NaN       NaN       NaN
#
# HORA        22:00:00  23:00:00
# FECHA
# 2024-10-01      15.2      15.2
# 2024-10-02      14.4      14.0
# 2024-10-05       NaN       NaN
#
# [3 rows x 24 columns]

# %% [markdown]
# ## pivot longer (.melt)

# %%
df_dca = pd.DataFrame({
    'Parcela': range(1, 4),
    'T1': [10.5, 11.2, 9.8],
    'T2': [12.0, 11.5, 13.1],
    'T3': [10.8, 12.2, 11.4]
})
df_dca
# Out:
#    Parcela    T1    T2    T3
# 0        1  10.5  12.0  10.8
# 1        2  11.2  11.5  12.2
# 2        3   9.8  13.1  11.4

# %%
df_dca.melt(id_vars    = ['Parcela'],
            value_vars = ['T1', 'T2', 'T3'],
            var_name   = 'Tratamiento', # nombre de la columna donde se almacenarán las columnas
            value_name = 'Rendimiento') # nombre de la columna donde se almacenarán los valores
# Out:
#    Parcela Tratamiento  Rendimiento
# 0        1          T1         10.5
# 1        2          T1         11.2
# 2        3          T1          9.8
# 3        1          T2         12.0
# 4        2          T2         11.5
# 5        3          T2         13.1
# 6        1          T3         10.8
# 7        2          T3         12.2
# 8        3          T3         11.4
